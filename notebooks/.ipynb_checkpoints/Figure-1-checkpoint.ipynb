# %%
# %pylab nbagg
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import sys
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(os.path.join(parent_dir, 'scripts'))
from F1_functions import *
from Allen_Connectome_metadata import *
from Mouse_dataset_metadata import *

# %%
#np.save('../data/AllenMouseConnectome/MASK.npy', MASK)

# %% [markdown]
# # Brain Plots

# %%
lims_max=np.abs(GC_RSC_pre).max()
lims_min=np.abs(GC_RSC_pre).min()
plot_brain(GC_RSC_pre,Template, msk,r'$GC$ - RSC pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
#fig, (ax1, ax2, ax3) = plt.subplots(1,3)
lims_max=np.abs(GM_RSC_pre).max()-np.abs(GM_RSC_pre).max()/5
lims_min=np.abs(GM_RSC_pre).min()
plot_brain(GM_RSC_pre,Template,msk,r'$GM$ - RSC pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
cmp='turbo'
lims_max=0.03#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.03#(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GC_RSC_post-GC_RSC_pre,Template,msk,r'$\Delta GC$ - RSC post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
plot_brain(GC_CTRL_post-GC_CTRL_pre,Template,msk,r'$\Delta GC$ - CTRL post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=0.02#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.02#5(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GM_RSC_post-GM_RSC_pre,Template,msk,r'$\Delta GM$ - RSC post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
plot_brain(GM_CTRL_post-GM_CTRL_pre,Template,msk,r'$\Delta GM$ - CTRL post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
groups = ['CTRL', 'RSC']  # Example groups
n_groups = len(groups)  # Number of groups

# Plotting violin plots with circles as individual data points and using the specified colors
fig, axes = plt.subplots(1, n_groups, figsize=(3.25* n_groups,2.1))

# Iterate over groups to plot violin plots with individual data points
for i, group in enumerate(groups):
    ax = axes[i]    
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gc_pre[group][RSN].values())] for RSN in RSNs]
    for j, RSN in enumerate(RSNs):

        color = CRSN[RSN]
        y = pre_data[j]
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=25, marker='o')
        
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    ax.set_xlabel('RSNs')
    ax.set_xticks(range(1, len(RSNs) + 1))
    ax.set_xticklabels(RSNs)

plt.tight_layout()
plt.savefig('../figures/Figure1/Mean_LGC_RSN_pre.png',dpi=400)
plt.show()

# %%
groups = ['CTRL', 'RSC']  # Example groups
n_groups = len(groups)  # Number of groups

# Plotting violin plots with circles as individual data points and using the specified colors
fig, axes = plt.subplots(1, n_groups, figsize=(3.25* n_groups,2.1))

# Iterate over groups to plot violin plots with individual data points
for i, group in enumerate(groups):
    ax = axes[i]    
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_pre[group][RSN].values())] for RSN in RSNs]
    for j, RSN in enumerate(RSNs):

        color = CRSN[RSN]
        y = pre_data[j]
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=25, marker='o')
        
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    #ax.spines['bottom'].set_visible(False if i < n_groups - 1 else True)  # Only show bottom axis on the last plot
    
    # Only set labels for the last subplot
    #if i == n_groups - 1:
    ax.set_xlabel('RSNs')
    ax.set_xticks(range(1, len(RSNs) + 1))
    ax.set_xticklabels(RSNs)

plt.tight_layout()
plt.savefig('../figures/Figure1/Var_LGC_RSN_pre.png',dpi=400)
plt.show()

# %%
# pre_data = 0#[np.mean(arr, axis=1)[0] for arr in list(d_gc_pre['RSC']['BF'].values())]
# post_data = 0#[np.mean(arr, axis=1)[0] for arr in list(d_gc_post['RSC']['BF'].values())]

# %%
groups = ['RSC', 'CTRL']  # Example groups
n_groups = len(groups)  # Number of groups

fig, axes = plt.subplots(1, n_groups, figsize=(3.25* n_groups,2.1))

for i, group in enumerate(groups):
    ax = axes[i]
        
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gc_pre[group][RSN].values())] for RSN in RSNs]
    post_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gc_post[group][RSN].values())] for RSN in RSNs]
    
    for j, RSN in enumerate(RSNs):
        color = CRSN[RSN]
        y = np.asarray(post_data[j])-np.asarray(pre_data[j])
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=35, marker='o')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    #ax.spines['bottom'].set_visible(False if i < n_groups - 1 else True)  # Only show bottom axis on the last plot
    
    # Only set labels for the last subplot
    #if i == n_groups - 1:
    ax.set_xlabel('RSNs')
    ax.set_xticks(range(1, len(RSNs) + 1))
    ax.set_xticklabels(RSNs)
    #else:
    #    ax.set_xticks([])
    ax.axhline(y=0, color='darkgray', linestyle='--')
    
    #ax.set_title('$\Delta GC$, %s'%group)
    ax.set_ylim((-0.035,0.015))

plt.tight_layout()
plt.savefig('../figures/Figure1/DeltaGC_RC_prepost.png',dpi=400)
plt.show()

# %%
groups = ['RSC', 'CTRL']  # Example groups
n_groups = len(groups)  # Number of groups

fig, axes = plt.subplots(1, n_groups, figsize=(3.25* n_groups,2.1))

for i, group in enumerate(groups):
    ax = axes[i]
        
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_pre[group][RSN].values())] for RSN in RSNs]
    post_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_post[group][RSN].values())] for RSN in RSNs]
    
    for j, RSN in enumerate(RSNs):
        color = CRSN[RSN]
        y = np.asarray(post_data[j])-np.asarray(pre_data[j])
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=35, marker='o')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Only set labels for the last subplot
    ax.set_xlabel('RSNs')
    ax.set_xticks(range(1, len(RSNs) + 1))
    ax.set_xticklabels(RSNs)

    ax.axhline(y=0, color='darkgray', linestyle='--')

    ax.set_ylim((-0.0225,0.008))

plt.tight_layout()
plt.savefig('../figures/Figure1/DeltaGM_RC_prepost.png',dpi=400)
plt.show()

# %%
groups = ['RSC', 'CTRL']  # Example groups
n_groups = len(groups)  # Number of groups

fig, axes = plt.subplots(n_groups, 1, figsize=(3.,1.85* n_groups))

for i, group in enumerate(groups):
    ax = axes[i]
        
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_pre[group][RSN].values())] for RSN in RSNs]
    post_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_post[group][RSN].values())] for RSN in RSNs]
    
    for j, RSN in enumerate(RSNs):
        color = CRSN[RSN]
        y = np.asarray(post_data[j])-np.asarray(pre_data[j])
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=35, marker='o')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Only set labels for the last subplot
    ax.set_xlabel('RSNs')
    ax.set_xticks(range(1, len(RSNs) + 1))
    ax.set_xticklabels(RSNs)

    ax.axhline(y=0, color='darkgray', linestyle='--')
    
    ax.set_title('$\Delta GM$, %s'%group)

plt.tight_layout()
plt.savefig('../figures/Figure1/DeltaGM_RC_prepost.png',dpi=400)
plt.show()

# %% [markdown]
# # SUPPLEMENTARY

# %%
import scipy

# %%
CL={'Th':'#F45A25','ACA':'#008080','RSC':'#9F00E7','CTRL':'#1A202E'} #Th, ACA, RSC, CTRL

# %%
mini=-0.0475
maxi=0.028

minii=-0.03525
maxii=0.012

plt.figure(figsize=(12,5))
plt.subplot(2,4,1)
plt.title('CTRL')
X=GC_CTRL_pre
Y=GC_CTRL_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['CTRL'])
plt.legend()
plt.xlabel('$GC$ pre')
plt.ylabel('$\Delta GC$ post-pre')
plt.ylim((mini,maxi))

plt.subplot(2,4,2)
plt.title('RSC')
X=GC_RSC_pre
Y=GC_RSC_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['RSC'])
plt.legend()
plt.xlabel('$GC$ pre')
plt.ylabel('$\Delta GC$ post-pre')
plt.ylim((mini,maxi))

plt.subplot(2,4,3)
plt.title('ACA')
X=GC_ACA_pre
Y=GC_ACA_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['ACA'])
plt.legend()
plt.xlabel('$GC$ pre')
plt.ylabel('$\Delta GC$ post-pre')
plt.ylim((mini,maxi))

plt.subplot(2,4,4)
plt.title('Th')
X=GC_Th_pre
Y=GC_Th_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['Th'])
plt.legend()
plt.xlabel('$GC$ pre')
plt.ylabel('$\Delta GC$ post-pre')
plt.ylim((mini,maxi))

plt.subplot(2,4,5)
plt.title('CTRL')
X=GM_CTRL_pre
Y=GM_CTRL_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['CTRL'])
plt.legend()
plt.xlabel('$GM$ pre')
plt.ylabel('$\Delta GM$ post-pre')
plt.ylim((minii,maxii))

plt.subplot(2,4,6)
plt.title('RSC')
X=GM_RSC_pre
Y=GM_RSC_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['RSC'])
plt.legend()
plt.xlabel('$GM$ pre')
plt.ylabel('$\Delta GM$ post-pre')
plt.ylim((minii,maxii))

plt.subplot(2,4,7)
plt.title('ACA')
X=GM_ACA_pre
Y=GM_ACA_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['ACA'])
plt.legend()
plt.xlabel('$GM$ pre')
plt.ylabel('$\Delta GM$ post-pre')
plt.ylim((minii,maxii))

plt.subplot(2,4,8)
plt.title('Th')
X=GM_Th_pre
Y=GM_Th_post
plt.scatter(X,Y-X,s=5,
            label='$r_s=%.3f$ \n $p<0.001$'%scipy.stats.spearmanr(X,Y-X)[0],color=CL['Th'])
plt.legend()
plt.xlabel('$GM$ pre')
plt.ylabel('$\Delta GM$ post-pre')
plt.ylim((minii,maxii))


plt.tight_layout()
plt.savefig('../figures/Figure1/Suppl_Correlations_prepost_effects.png',dpi=300)
plt.show()

# %%
lims_max=np.abs(GC_RSC_pre).max()
lims_min=np.abs(GC_RSC_pre).min()
plot_brain(GC_RSC_pre,Template,msk,r'$GC$ - RSC pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
#fig, (ax1, ax2, ax3) = plt.subplots(1,3)
lims_max=np.abs(GM_RSC_pre).max()
lims_min=np.abs(GM_RSC_pre).min()
plot_brain(GM_RSC_pre,Template,msk,r'$GM$ - RSC pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=np.abs(GC_ACA_pre).max()
lims_min=np.abs(GC_ACA_pre).min()
plot_brain(GC_ACA_pre,Template,msk,r'$GC$ - ACA pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
#fig, (ax1, ax2, ax3) = plt.subplots(1,3)
lims_max=np.abs(GM_ACA_pre).max()
lims_min=np.abs(GM_ACA_pre).min()
plot_brain(GM_ACA_pre,Template,msk,r'$GM$ - ACA pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=np.abs(GC_CTRL_pre).max()
lims_min=np.abs(GC_CTRL_pre).min()
plot_brain(GC_CTRL_pre,Template,msk,r'$GC$ - CTRL pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
#fig, (ax1, ax2, ax3) = plt.subplots(1,3)
lims_max=np.abs(GM_CTRL_pre).max()
lims_min=np.abs(GM_CTRL_pre).min()
plot_brain(GM_CTRL_pre,Template,msk,r'$GM$ - CTRL pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=np.abs(GC_Th_pre).max()
lims_min=np.abs(GC_Th_pre).min()
plot_brain(GC_Th_pre,Template,MASK,r'$GC$ - Th pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
#fig, (ax1, ax2, ax3) = plt.subplots(1,3)
lims_max=np.abs(GM_Th_pre).max()
lims_min=np.abs(GM_Th_pre).min()
plot_brain(GM_Th_pre,Template,MASK,r'$GM$ - Th pre',r'',lims_min,lims_max,'viridis','on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
cmp='turbo'
lims_max=0.03#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.03#(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GC_ACA_post-GC_ACA_pre,Template,msk,r'$\Delta GC$ - ACA post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
cmp='turbo'
lims_max=0.02#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.02#(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GC_Th_post-GC_Th_pre,Template,MASK,r'$\Delta GC$ - Th post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=0.02#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.02#5(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GM_ACA_post-GM_ACA_pre,Template,msk,r'$\Delta GM$ - ACA post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
lims_max=0.005#(GC_RSC_post-GC_RSC_pre).max()
lims_min=-0.005#5(GC_RSC_post-GC_RSC_pre).min()

# %%
plot_brain(GM_Th_post-GM_Th_pre,Template,MASK,r'$\Delta GM$ - Th post-pre',r'',lims_min,lims_max,cmp,'on','coronal')
#plt.show()  # This should NOT be called inside plot_something()

# %%
groups = ['CTRL', 'RSC', 'ACA','Th']  # Example groups
n_groups = len(groups)  # Number of groups

fig, axes = plt.subplots(n_groups, 1, figsize=(3.,1.85* n_groups))

for i, group in enumerate(groups):
    ax = axes[i]
        
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gc_pre[group][RSN].values())] for RSN in RSNs]
    post_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gc_post[group][RSN].values())] for RSN in RSNs]
    
    for j, RSN in enumerate(RSNs):
        color = CRSN[RSN]
        y = np.asarray(post_data[j])-np.asarray(pre_data[j])
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=35, marker='o')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False if i < n_groups - 1 else True)  # Only show bottom axis on the last plot
    
    # Only set labels for the last subplot
    if i == n_groups - 1:
        ax.set_xlabel('RSNs')
        ax.set_xticks(range(1, len(RSNs) + 1))
        ax.set_xticklabels(RSNs)
    else:
        ax.set_xticks([])
    ax.axhline(y=0, color='darkgray', linestyle='--')
    
    ax.set_title('$\Delta GC$, %s'%group)

plt.tight_layout()
plt.savefig('../figures/Figure1/DeltaGC_RSN_prepost.png',dpi=400)
plt.show()

# %%
groups = ['CTRL', 'RSC', 'ACA','Th']  # Example groups
n_groups = len(groups)  # Number of groups

fig, axes = plt.subplots(n_groups, 1, figsize=(3.,1.85* n_groups))

for i, group in enumerate(groups):
    ax = axes[i]
        
    pre_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_pre[group][RSN].values())] for RSN in RSNs]
    post_data = [[np.mean(arr, axis=1)[0] for arr in list(d_gm_post[group][RSN].values())] for RSN in RSNs]
    
    for j, RSN in enumerate(RSNs):
        color = CRSN[RSN]
        y = np.asarray(post_data[j])-np.asarray(pre_data[j])
        x = np.random.normal(j + 1, 0.08, size=len(y))  # Spread points around the x position
        ax.scatter(x, y, alpha=0.7, color=color, linewidth=0.75, edgecolor='black', s=35, marker='o')
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False if i < n_groups - 1 else True)  # Only show bottom axis on the last plot
    
    # Only set labels for the last subplot
    if i == n_groups - 1:
        ax.set_xlabel('RSNs')
        ax.set_xticks(range(1, len(RSNs) + 1))
        ax.set_xticklabels(RSNs)
    else:
        ax.set_xticks([])
    ax.axhline(y=0, color='darkgray', linestyle='--')
    
    ax.set_title('$\Delta GM$, %s'%group)

plt.tight_layout()
plt.savefig('../figures/Figure1/DeltaGM_RSN_prepost.png',dpi=400)
plt.show()
